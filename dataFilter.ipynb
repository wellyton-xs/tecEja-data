# %%
import pandas as pd

questionarios = pd.read_csv('questoes.csv')

dados_dos_questionarios_filtrados = questionarios[['nome','questionario','Created Date','escola', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']]

dados_dos_questionarios_filtrados_copy = dados_dos_questionarios_filtrados.copy()

dados_dos_questionarios_filtrados_copy['Created Date'] = dados_dos_questionarios_filtrados_copy['Created Date'].str.split('T').str[0]

primeiro_questionario = dados_dos_questionarios_filtrados_copy[dados_dos_questionarios_filtrados_copy['questionario'] == '["1"]']
segundo_questionario = dados_dos_questionarios_filtrados_copy[dados_dos_questionarios_filtrados_copy['questionario'] == '["2"]']
terceiro_questionario = dados_dos_questionarios_filtrados_copy[dados_dos_questionarios_filtrados_copy['questionario'] == '["3"]']

# %% [markdown]
# # QUESTIONARIO UM

# %%
dados_dos_questionarios_filtrados
# Out:
#                                                  nome questionario  \
# 0                    Maico Antony Gouveia de Oliveira        ["2"]
# 1                          Grazielle Braz de Oliveira        ["2"]
# 2   Lívia Samily Delfino, Bruna Gomes Viera, Maria...        ["3"]
# 3                           jose pedro valerio cabral        ["1"]
# 4                      tayna marques da silva pereira        ["1"]
# ..                                                ...          ...
# 93                           Ana Beatriz Duarte Silva        ["2"]
# 94                            José Yan Ferreira Leite        ["2"]
# 95                             Micaias Lopes Oliveira        ["1"]
# 96                    luis carlos ferreira dos santos        ["3"]
# 97                        sandreilson justino ribeiro        ["2"]
#
#             Created Date                           escola r1 r2 r3 r4 r5 r6  \
# 0   2023-08-25T11:27:08Z      IFPB Campus Princesa Isabel  C  A  B  B  C  A
# ...

# %% [markdown]
# ## GABARITO
#
#     1 – D
#     2 – A
#     3 – D
#     4 – B
#     5 – B
#     6 – B
#     7 – D
#     8 – A
#     9 – B
#     10 – B

# %%
primeiro_questionario_copy = primeiro_questionario.copy()

primeiro_questionario_copy.loc[primeiro_questionario_copy['r1'] == 'D', 'r1'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r2'] == 'A', 'r2'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r3'] == 'D', 'r3'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r4'] == 'B', 'r4'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r5'] == 'B', 'r5'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r6'] == 'B', 'r6'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r7'] == 'D', 'r7'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r8'] == 'A', 'r8'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r9'] == 'B', 'r9'] = 'ACERTO'
primeiro_questionario_copy.loc[primeiro_questionario_copy['r10'] == 'B', 'r10'] = 'ACERTO'

#correção = segundo_questionario.mask(segundo_questionario == 'C', 'ACERTO')

primeiro_questionario_copy
# Out:
#                                        nome questionario Created Date  \
# 3                 jose pedro valerio cabral        ["1"]   2023-09-13
# 4            tayna marques da silva pereira        ["1"]   2023-09-13
# 10                    talita da silva veras        ["1"]   2023-08-18
# 14                     antonio alves casusa        ["1"]   2023-09-13
# 15              sandreilson justino ribeiro        ["1"]   2023-09-13
# 20                  Jéssica Meneses de Lima        ["1"]   2023-08-18
# 22                Gabriel da Silva Laurindo        ["1"]   2023-08-18
# 27                 Ana Beatriz Duarte Silva        ["1"]   2023-08-18
# 29                            emilly tayna         ["1"]   2023-08-18
# 30           ALISSON MATEUS DOS SANTOS LUIZ        ["1"]   2023-09-13
# 32                edilene da silva souza           ["1"]   2023-09-13
# 35                 marialilianebarbosasilva        ["1"]   2023-09-13
# ...

# %%
acertos_questionario1_questao1 = primeiro_questionario_copy['r1'].value_counts()['ACERTO']
acertos_questionario1_questao2 = primeiro_questionario_copy['r2'].value_counts()['ACERTO']
acertos_questionario1_questao3 = primeiro_questionario_copy['r3'].value_counts()['ACERTO']
acertos_questionario1_questao4 = primeiro_questionario_copy['r4'].value_counts()['ACERTO']
acertos_questionario1_questao5 = primeiro_questionario_copy['r5'].value_counts()['ACERTO']
acertos_questionario1_questao6 = primeiro_questionario_copy['r6'].value_counts()['ACERTO']
acertos_questionario1_questao7 = primeiro_questionario_copy['r7'].value_counts()['ACERTO']
acertos_questionario1_questao8 = primeiro_questionario_copy['r8'].value_counts()['ACERTO']
acertos_questionario1_questao9 = primeiro_questionario_copy['r9'].value_counts()['ACERTO']
acertos_questionario1_questao10 = primeiro_questionario_copy['r10'].value_counts()['ACERTO']

# %%
print(f'''ACERTOS:

questão 1:{acertos_questionario1_questao1}
questão 2: {acertos_questionario1_questao2} 
questão 3: {acertos_questionario1_questao3} 
questão 4: {acertos_questionario1_questao4} 
questão 5: {acertos_questionario1_questao5} 
questão 6: {acertos_questionario1_questao6}
questão 7: {acertos_questionario1_questao7}
questão 8: {acertos_questionario1_questao8}
questão 9: {acertos_questionario1_questao9}
questão 10: {acertos_questionario1_questao10}
   ''')
# Out:
# ACERTOS:
#
# questão 1:25
# questão 2: 29
# questão 3: 16
# questão 4: 12
# questão 5: 21
# questão 6: 21
# questão 7: 9
# questão 8: 8
# questão 9: 16
# questão 10: 10

# %%
primeiro_questionario_copy
# Out:
#                                        nome questionario Created Date  \
# 3                 jose pedro valerio cabral        ["1"]   2023-09-13
# 4            tayna marques da silva pereira        ["1"]   2023-09-13
# 10                    talita da silva veras        ["1"]   2023-08-18
# 14                     antonio alves casusa        ["1"]   2023-09-13
# 15              sandreilson justino ribeiro        ["1"]   2023-09-13
# 20                  Jéssica Meneses de Lima        ["1"]   2023-08-18
# 22                Gabriel da Silva Laurindo        ["1"]   2023-08-18
# 27                 Ana Beatriz Duarte Silva        ["1"]   2023-08-18
# 29                            emilly tayna         ["1"]   2023-08-18
# 30           ALISSON MATEUS DOS SANTOS LUIZ        ["1"]   2023-09-13
# 32                edilene da silva souza           ["1"]   2023-09-13
# 35                 marialilianebarbosasilva        ["1"]   2023-09-13
# ...

# %% [markdown]
# # QUESTIONARIO DOIS

# %%
segundo_questionario.head(5)
# Out:
#                                nome questionario Created Date  \
# 0  Maico Antony Gouveia de Oliveira        ["2"]   2023-08-25
# 1        Grazielle Braz de Oliveira        ["2"]   2023-08-25
# 5        ROSILENE LEONARDO DA SILVA        ["2"]   2023-09-13
# 6        Ana paula de Araujo soares        ["2"]   2023-09-13
# 8  Plínio Manoel Cordeiro Rodrigues        ["2"]   2023-08-25
#
#                                       escola r1 r2 r3   r4 r5 r6 r7 r8 r9 r10
# 0                IFPB Campus Princesa Isabel  C  A  B    B  C  A  B  A  B   B
# 1                IFPB Campus Princesa Isabel  B  A  B    B  C  A  B  C  C   C
# 5            MINISTRO ALCIDES VIERA CARNEIRO  A  C  D    D  B  B  D  A  B   C
# 6                           Alcides Carneiro  A  D  A    B  B  B  D  C  B   C
# 8  Instituto Federal Paraíba Princesa Isabel  C  A  B  NaN  B  A  B  C  B   B

# %% [markdown]
# ## GABARITO
#     2º Questionário
#
#     1 – C
#     2 – A
#     3 – B
#     4 – B
#     5 – C
#     6 – A
#     7 – B
#     8 – A
#     9 – B
#     10 – B

# %%
segundo_questionario_copy = segundo_questionario.copy()

segundo_questionario_copy.loc[segundo_questionario_copy['r1'] == 'C', 'r1'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r2'] == 'A', 'r2'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r3'] == 'B', 'r3'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r4'] == 'B', 'r4'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r5'] == 'C', 'r5'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r6'] == 'A', 'r6'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r7'] == 'B', 'r7'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r8'] == 'A', 'r8'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r9'] == 'B', 'r9'] = 'ACERTO'
segundo_questionario_copy.loc[segundo_questionario_copy['r10'] == 'B', 'r10'] = 'ACERTO'

#correção = segundo_questionario.mask(segundo_questionario == 'C', 'ACERTO')

segundo_questionario_copy
# Out:
#                                        nome questionario Created Date  \
# 0          Maico Antony Gouveia de Oliveira        ["2"]   2023-08-25
# 1                Grazielle Braz de Oliveira        ["2"]   2023-08-25
# 5                ROSILENE LEONARDO DA SILVA        ["2"]   2023-09-13
# 6                Ana paula de Araujo soares        ["2"]   2023-09-13
# 8          Plínio Manoel Cordeiro Rodrigues        ["2"]   2023-08-25
# 9                    Micaias Lopes Oliveira        ["2"]   2023-08-25
# 12                  idelia ferndes da silva        ["2"]   2023-09-13
# 17                            kaique barros        ["2"]   2023-08-25
# 18    joao artur de araujo caetano ferreira        ["2"]   2023-09-13
# 23                   edilene da silva souza        ["2"]   2023-09-13
# 24           Lívia Samily Delfino Carneiro         ["2"]   2023-08-25
# 26           ALISSON MATEUS DOS SANTOS LUIZ        ["2"]   2023-09-13
# ...

# %%
'''
acertos_questao1 = segundo_questionario_copy.groupby(['r2']).size()
acertos_questao2 = segundo_questionario_copy.groupby(['r2']).size()
acertos_questao3 = segundo_questionario_copy.groupby(['r3']).size()
acertos_questao4 = segundo_questionario_copy.groupby(['r4']).size()
acertos_questao5 = segundo_questionario_copy.groupby(['r5']).size()
acertos_questao6 = segundo_questionario_copy.groupby(['r6']).size()
acertos_questao7 = segundo_questionario_copy.groupby(['r7']).size()
acertos_questao8 = segundo_questionario_copy.groupby(['r8']).size()
acertos_questao9 = segundo_questionario_copy.groupby(['r9']).size()
acertos_questao10 = segundo_questionario_copy.groupby(['r10']).size()
'''

acertos_questao1 = segundo_questionario_copy['r1'].value_counts()['ACERTO']
acertos_questao2 = segundo_questionario_copy['r2'].value_counts()['ACERTO']
acertos_questao3 = segundo_questionario_copy['r3'].value_counts()['ACERTO']
acertos_questao4 = segundo_questionario_copy['r4'].value_counts()['ACERTO']
acertos_questao5 = segundo_questionario_copy['r5'].value_counts()['ACERTO']
acertos_questao6 = segundo_questionario_copy['r6'].value_counts()['ACERTO']
acertos_questao7 = segundo_questionario_copy['r7'].value_counts()['ACERTO']
acertos_questao8 = segundo_questionario_copy['r8'].value_counts()['ACERTO']
acertos_questao9 = segundo_questionario_copy['r9'].value_counts()['ACERTO']
acertos_questao10 = segundo_questionario_copy['r10'].value_counts()['ACERTO']

# %%
print(f'''ACERTOS:

questão 1:{acertos_questao1}
questão 2: {acertos_questao2} 
questão 3: {acertos_questao3} 
questão 4: {acertos_questao4} 
questão 5: {acertos_questao5} 
questão 6: {acertos_questao6}
questão 7: {acertos_questao7}
questão 8: {acertos_questao8}
questão 9: {acertos_questao9}
questão 10: {acertos_questao10}
   ''')
# Out:
# ACERTOS:
#
# questão 1:18
# questão 2: 21
# questão 3: 24
# questão 4: 22
# questão 5: 18
# questão 6: 25
# questão 7: 17
# questão 8: 5
# questão 9: 17
# questão 10: 10

# %%
segundo_questionario_copy.describe()
# Out:
#                                     nome questionario Created Date  \
# count                                 40           40           40
# unique                                40            1            2
# top     Maico Antony Gouveia de Oliveira        ["2"]   2023-08-25
# freq                                   1           40           24
#
#                              escola      r1      r2      r3      r4      r5  \
# count                            40      40      40      39      37      39
# unique                           27       4       4       4       4       4
# top     IFPB Campus Princesa Isabel  ACERTO  ACERTO  ACERTO  ACERTO  ACERTO
# freq                              5      18      21      24      22      18
#
#             r6      r7  r8      r9 r10
# count       39      39  39      39  40
# unique       3       4   4       4   4
# top     ACERTO  ACERTO   C  ACERTO   C
# freq        25      17  22      17  18

# %% [markdown]
# # QUESTIONARIO 3

# %%
terceiro_questionario
# Out:
#                                                  nome questionario  \
# 2   Lívia Samily Delfino, Bruna Gomes Viera, Maria...        ["3"]
# 7   Talita da Silva Veras; Micaias Oliveira; Erick...        ["3"]
# 11                       sandreilson justino ribeiro         ["3"]
# 13                     tayna marques da silva pereira        ["3"]
# 16                                   nadya e tatiana         ["3"]
# 19                               simone sabrina gomes        ["3"]
# 21                         ROSILENE LEONARDO DA SILVA        ["3"]
# 25                                                NaN        ["3"]
# 31              joao artur de araujo caetano ferreira        ["3"]
# 36   Maico Antony, Jéssica Meneses, Thaís de Oliveira        ["3"]
# 44                          Anapaula de Araujo Soares        ["3"]
# 45  Marcos Antonio Pereira Nunes Florentino, Jose ...        ["3"]
# 51                                     antonio casusa        ["3"]
# ...

# %% [markdown]
# ## GABARITO
#
#     3º Questionário
#
#     1 – C
#     2 – A
#     3 – A
#     4 – B
#     5 – C
#     6 – A
#     7 – B
#     8 – A
#     9 – B
#     10 – B

# %%
terceiro_questionario_copy = terceiro_questionario.copy()

terceiro_questionario_copy.loc[terceiro_questionario_copy['r1'] == 'C', 'r1'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r2'] == 'A', 'r2'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r3'] == 'A', 'r3'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r4'] == 'B', 'r4'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r5'] == 'C', 'r5'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r6'] == 'A', 'r6'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r7'] == 'B', 'r7'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r8'] == 'A', 'r8'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r9'] == 'B', 'r9'] = 'ACERTO'
terceiro_questionario_copy.loc[terceiro_questionario_copy['r10'] == 'B', 'r10'] = 'ACERTO'

terceiro_questionario_copy
# Out:
#                                                  nome questionario  \
# 2   Lívia Samily Delfino, Bruna Gomes Viera, Maria...        ["3"]
# 7   Talita da Silva Veras; Micaias Oliveira; Erick...        ["3"]
# 11                       sandreilson justino ribeiro         ["3"]
# 13                     tayna marques da silva pereira        ["3"]
# 16                                   nadya e tatiana         ["3"]
# 19                               simone sabrina gomes        ["3"]
# 21                         ROSILENE LEONARDO DA SILVA        ["3"]
# 25                                                NaN        ["3"]
# 31              joao artur de araujo caetano ferreira        ["3"]
# 36   Maico Antony, Jéssica Meneses, Thaís de Oliveira        ["3"]
# 44                          Anapaula de Araujo Soares        ["3"]
# 45  Marcos Antonio Pereira Nunes Florentino, Jose ...        ["3"]
# 51                                     antonio casusa        ["3"]
# ...

# %%
acertos_questionario3_questao1 = terceiro_questionario_copy['r1'].value_counts()['ACERTO']
acertos_questionario3_questao2 = terceiro_questionario_copy['r2'].value_counts()['ACERTO']
acertos_questionario3_questao3 = terceiro_questionario_copy['r3'].value_counts()['ACERTO']
acertos_questionario3_questao4 = terceiro_questionario_copy['r4'].value_counts()['ACERTO']
acertos_questionario3_questao5 = terceiro_questionario_copy['r5'].value_counts()['ACERTO']
acertos_questionario3_questao6 = terceiro_questionario_copy['r6'].value_counts()['ACERTO']
acertos_questionario3_questao7 = terceiro_questionario_copy['r7'].value_counts()['ACERTO']
acertos_questionario3_questao8 = terceiro_questionario_copy['r8'].value_counts()['ACERTO']
acertos_questionario3_questao9 = terceiro_questionario_copy['r9'].value_counts()['ACERTO']
acertos_questionario3_questao10 = terceiro_questionario_copy['r10'].value_counts()['ACERTO']

# %%
print(f'''ACERTOS:

questão 1:{acertos_questionario3_questao1}
questão 2: {acertos_questionario3_questao2} 
questão 3: {acertos_questionario3_questao3} 
questão 4: {acertos_questionario3_questao4} 
questão 5: {acertos_questionario3_questao5} 
questão 6: {acertos_questionario3_questao6}
questão 7: {acertos_questionario3_questao7}
questão 8: {acertos_questionario3_questao8}
questão 9: {acertos_questionario3_questao9}
questão 10: {acertos_questionario3_questao10}
   ''')
# Out:
# ACERTOS:
#
# questão 1:9
# questão 2: 9
# questão 3: 9
# questão 4: 8
# questão 5: 12
# questão 6: 9
# questão 7: 7
# questão 8: 8
# questão 9: 8
# questão 10: 10

# %%
terceiro_questionario_copy.describe()
# Out:
#                                                      nome questionario  \
# count                                                  22           23
# unique                                                 22            1
# top     Lívia Samily Delfino, Bruna Gomes Viera, Maria...        ["3"]
# freq                                                    1           23
#
#        Created Date                   escola  r1      r2      r3  r4      r5  \
# count            23                       22  23      23      23  23      23
# unique            3                       17   4       4       4   4       4
# top      2023-09-13  alcides vieira carneiro   A  ACERTO  ACERTO   D  ACERTO
# freq             14                        4  10       9       9   9      12
#
#         r6  r7  r8      r9     r10
# count   23  23  23      23      23
# unique   4   4   4       4       4
# top      B   D   C  ACERTO  ACERTO
# freq    10   8   8       8      10

# %% [markdown]
# # EJA analise

# %% [markdown]
# ## PRIMEIRO QUESTIONÁRIO

# %%
primeiro_questionario_eja = primeiro_questionario[primeiro_questionario['Created Date'] == '2023-09-13']
segundo_questionario_eja = segundo_questionario[segundo_questionario['Created Date'] == '2023-09-13']
terceiro_questionario_eja = terceiro_questionario[terceiro_questionario['Created Date'] == '2023-09-13']

# %%
primeiro_questionario_eja.count()
# Out:
# nome            17
# questionario    17
# Created Date    17
# escola          17
# r1              17
# r2              17
# r3              17
# r4              17
# r5              17
# r6              17
# r7              17
# r8              17
# r9              17
# r10             17
# dtype: int64

# %%
primeiro_questionario_eja_copy = primeiro_questionario_eja.copy()

primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r1'] == 'D', 'r1'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r2'] == 'A', 'r2'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r3'] == 'D', 'r3'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r4'] == 'B', 'r4'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r5'] == 'B', 'r5'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r6'] == 'B', 'r6'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r7'] == 'D', 'r7'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r8'] == 'A', 'r8'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r9'] == 'B', 'r9'] = 'ACERTO'
primeiro_questionario_eja_copy.loc[primeiro_questionario_eja_copy['r10'] == 'B', 'r10'] = 'ACERTO'

primeiro_questionario_eja_copy.head(3)
# Out:
#                               nome questionario Created Date  \
# 3        jose pedro valerio cabral        ["1"]   2023-09-13
# 4   tayna marques da silva pereira        ["1"]   2023-09-13
# 14            antonio alves casusa        ["1"]   2023-09-13
#
#                              escola      r1      r2 r3      r4      r5  \
# 3           alcides vieira carneiro  ACERTO       D  B       D       A
# 4   ministro alcides viera carneiro  ACERTO  ACERTO  B  ACERTO  ACERTO
# 14                            olcde       B  ACERTO  B       D       C
#
#         r6 r7 r8      r9     r10
# 3   ACERTO  B  B       C       C
# 4        D  B  C  ACERTO       A
# 14       C  B  D  ACERTO  ACERTO

# %%
acertos_questionario1_eja_questao1 = primeiro_questionario_eja_copy['r1'].value_counts()['ACERTO']
acertos_questionario1_eja_questao2 = primeiro_questionario_eja_copy['r2'].value_counts()['ACERTO']
acertos_questionario1_eja_questao3 = primeiro_questionario_eja_copy['r3'].value_counts()['ACERTO']
acertos_questionario1_eja_questao4 = primeiro_questionario_eja_copy['r4'].value_counts()['ACERTO']
acertos_questionario1_eja_questao5 = primeiro_questionario_eja_copy['r5'].value_counts()['ACERTO']
acertos_questionario1_eja_questao6 = primeiro_questionario_eja_copy['r6'].value_counts()['ACERTO']
acertos_questionario1_eja_questao7 = primeiro_questionario_eja_copy['r7'].value_counts()['ACERTO']
acertos_questionario1_eja_questao8 = primeiro_questionario_eja_copy['r8'].value_counts()['ACERTO']
acertos_questionario1_eja_questao9 = primeiro_questionario_eja_copy['r9'].value_counts()['ACERTO']
acertos_questionario1_eja_questao10 = primeiro_questionario_eja_copy['r10'].value_counts()['ACERTO']

# %%
print(f'''ACERTOS:

questão 1:{acertos_questionario1_eja_questao1}
questão 2: {acertos_questionario1_eja_questao2} 
questão 3: {acertos_questionario1_eja_questao3} 
questão 4: {acertos_questionario1_eja_questao4} 
questão 5: {acertos_questionario1_eja_questao5} 
questão 6: {acertos_questionario1_eja_questao6}
questão 7: {acertos_questionario1_eja_questao7}
questão 8: {acertos_questionario1_eja_questao8}
questão 9: {acertos_questionario1_eja_questao10}
questão 10: {acertos_questionario1_eja_questao10}
''')
# Out:
# ACERTOS:
#
# questão 1:10
# questão 2: 11
# questão 3: 4
# questão 4: 5
# questão 5: 4
# questão 6: 6
# questão 7: 5
# questão 8: 3
# questão 9: 2
# questão 10: 2

# %% [markdown]
# ## SEGUNDO QUESTIONÁRIO

# %%
segundo_questionario_eja.count()
# Out:
# nome            16
# questionario    16
# Created Date    16
# escola          16
# r1              16
# r2              16
# r3              15
# r4              15
# r5              15
# r6              15
# r7              15
# r8              15
# r9              15
# r10             16
# dtype: int64

# %%
segundo_questionario_eja_copy = segundo_questionario_eja.copy()

segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r1'] == 'D', 'r1'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r2'] == 'A', 'r2'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r3'] == 'D', 'r3'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r4'] == 'B', 'r4'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r5'] == 'B', 'r5'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r6'] == 'B', 'r6'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r7'] == 'D', 'r7'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r8'] == 'A', 'r8'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r9'] == 'B', 'r9'] = 'ACERTO'
segundo_questionario_eja_copy.loc[segundo_questionario_eja_copy['r10'] == 'B', 'r10'] = 'ACERTO'

primeiro_questionario_eja_copy.head(3)
# Out:
#                               nome questionario Created Date  \
# 3        jose pedro valerio cabral        ["1"]   2023-09-13
# 4   tayna marques da silva pereira        ["1"]   2023-09-13
# 14            antonio alves casusa        ["1"]   2023-09-13
#
#                              escola      r1      r2 r3      r4      r5  \
# 3           alcides vieira carneiro  ACERTO       D  B       D       A
# 4   ministro alcides viera carneiro  ACERTO  ACERTO  B  ACERTO  ACERTO
# 14                            olcde       B  ACERTO  B       D       C
#
#         r6 r7 r8      r9     r10
# 3   ACERTO  B  B       C       C
# 4        D  B  C  ACERTO       A
# 14       C  B  D  ACERTO  ACERTO

# %%
acertos_questionario2_eja_questao1 = segundo_questionario_eja_copy['r1'].value_counts()['ACERTO']
acertos_questionario2_eja_questao2 = segundo_questionario_eja_copy['r2'].value_counts()['ACERTO']
acertos_questionario2_eja_questao3 = segundo_questionario_eja_copy['r3'].value_counts()['ACERTO']
acertos_questionario2_eja_questao4 = segundo_questionario_eja_copy['r4'].value_counts()['ACERTO']
acertos_questionario2_eja_questao5 = segundo_questionario_eja_copy['r5'].value_counts()['ACERTO']
acertos_questionario2_eja_questao6 = segundo_questionario_eja_copy['r6'].value_counts()['ACERTO']
acertos_questionario2_eja_questao7 = segundo_questionario_eja_copy['r7'].value_counts()['ACERTO']
acertos_questionario2_eja_questao8 = segundo_questionario_eja_copy['r8'].value_counts()['ACERTO']
acertos_questionario2_eja_questao9 = segundo_questionario_eja_copy['r9'].value_counts()['ACERTO']
acertos_questionario2_eja_questao10 = segundo_questionario_eja_copy['r10'].value_counts()['ACERTO']

# %%
print(f'''ACERTOS:

questão 1:{acertos_questionario2_eja_questao1}
questão 2: {acertos_questionario2_eja_questao2} 
questão 3: {acertos_questionario2_eja_questao3} 
questão 4: {acertos_questionario2_eja_questao4} 
questão 5: {acertos_questionario2_eja_questao5} 
questão 6: {acertos_questionario2_eja_questao6}
questão 7: {acertos_questionario2_eja_questao7}
questão 8: {acertos_questionario2_eja_questao8}
questão 9: {acertos_questionario2_eja_questao10}
questão 10: {acertos_questionario2_eja_questao10}
''')
# Out:
# ACERTOS:
#
# questão 1:3
# questão 2: 4
# questão 3: 2
# questão 4: 6
# questão 5: 10
# questão 6: 5
# questão 7: 11
# questão 8: 1
# questão 9: 4
# questão 10: 4

# %% [markdown]
# ## TERCEIRO QUESTIONÁRIO

# %%
terceiro_questionario_eja
# Out:
#                                      nome questionario Created Date  \
# 11           sandreilson justino ribeiro         ["3"]   2023-09-13
# 13         tayna marques da silva pereira        ["3"]   2023-09-13
# 16                       nadya e tatiana         ["3"]   2023-09-13
# 19                   simone sabrina gomes        ["3"]   2023-09-13
# 21             ROSILENE LEONARDO DA SILVA        ["3"]   2023-09-13
# 31  joao artur de araujo caetano ferreira        ["3"]   2023-09-13
# 44              Anapaula de Araujo Soares        ["3"]   2023-09-13
# 51                         antonio casusa        ["3"]   2023-09-13
# 52              jose pedro valerio cabral        ["3"]   2023-09-13
# 54                 edilene da silva souza        ["3"]   2023-09-13
# 64              maria das dores maia gato        ["3"]   2023-09-13
# 66      maria charline pereira dos santos        ["3"]   2023-09-13
# 74         alisson mateus dos santos luiz        ["3"]   2023-09-13
# ...

# %%
terceiro_questionario_eja_copy = terceiro_questionario_eja.copy()

terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r1'] == 'D', 'r1'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r2'] == 'A', 'r2'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r3'] == 'D', 'r3'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r4'] == 'B', 'r4'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r5'] == 'B', 'r5'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r6'] == 'B', 'r6'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r7'] == 'D', 'r7'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r8'] == 'A', 'r8'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r9'] == 'B', 'r9'] = 'ACERTO'
terceiro_questionario_eja_copy.loc[terceiro_questionario_eja_copy['r10'] == 'C', 'r10'] = 'ACERTO'

terceiro_questionario_eja_copy.head(3)
# Out:
#                               nome questionario Created Date  \
# 11    sandreilson justino ribeiro         ["3"]   2023-09-13
# 13  tayna marques da silva pereira        ["3"]   2023-09-13
# 16                nadya e tatiana         ["3"]   2023-09-13
#
#                                     escola r1      r2      r3      r4      r5  \
# 11       ministro alcides vieira carneiro   A  ACERTO  ACERTO       D  ACERTO
# 13  EEE F ministro alcides vieira carneiro  B       B  ACERTO  ACERTO       A
# 16   eeef ministro alcides vieira carneiro  B       B       C       C  ACERTO
#
#         r6      r7 r8      r9     r10
# 11  ACERTO  ACERTO  D       A       A
# 13       A  ACERTO  B       D       B
# 16  ACERTO       A  B  ACERTO  ACERTO

# %%
acertos_questionario3_eja_questao1 = segundo_questionario_eja_copy['r1'].value_counts()['ACERTO']
acertos_questionario3_eja_questao2 = segundo_questionario_eja_copy['r2'].value_counts()['ACERTO']
acertos_questionario3_eja_questao3 = segundo_questionario_eja_copy['r3'].value_counts()['ACERTO']
acertos_questionario3_eja_questao4 = segundo_questionario_eja_copy['r4'].value_counts()['ACERTO']
acertos_questionario3_eja_questao5 = segundo_questionario_eja_copy['r5'].value_counts()['ACERTO']
acertos_questionario3_eja_questao6 = segundo_questionario_eja_copy['r6'].value_counts()['ACERTO']
acertos_questionario3_eja_questao7 = segundo_questionario_eja_copy['r7'].value_counts()['ACERTO']
acertos_questionario3_eja_questao8 = segundo_questionario_eja_copy['r8'].value_counts()['ACERTO']
acertos_questionario3_eja_questao9 = segundo_questionario_eja_copy['r9'].value_counts()['ACERTO']
acertos_questionario3_eja_questao10 = segundo_questionario_eja_copy['r10'].value_counts()['ACERTO']

# %%
print(f'''ACERTOS:

questão 1:{acertos_questionario3_eja_questao1}
questão 3: {acertos_questionario3_eja_questao3} 
questão 3: {acertos_questionario3_eja_questao3} 
questão 4: {acertos_questionario3_eja_questao4} 
questão 5: {acertos_questionario3_eja_questao5} 
questão 6: {acertos_questionario3_eja_questao6}
questão 7: {acertos_questionario3_eja_questao7}
questão 8: {acertos_questionario3_eja_questao8}
questão 9: {acertos_questionario3_eja_questao10}
questão 10: {acertos_questionario3_eja_questao10}
''')
# Out:
# ACERTOS:
#
# questão 1:3
# questão 3: 2
# questão 3: 2
# questão 4: 6
# questão 5: 10
# questão 6: 5
# questão 7: 11
# questão 8: 1
# questão 9: 4
# questão 10: 4
